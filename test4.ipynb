# %% [markdown]
# <a href="https://colab.research.google.com/github/yoshito-ito/training/blob/master/test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow をインストール

# !pip install -q tensorflow-gpu==2.0.0-beta1
import tensorflow as tf
# Out:
#      |████████████████████████████████| 348.9MB 50kB/s
#      |████████████████████████████████| 501kB 41.4MB/s
#      |████████████████████████████████| 3.1MB 64.2MB/s

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow と tf.keras のインポート
import tensorflow as tf
from tensorflow import keras

# ヘルパーライブラリのインポート
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.2.0-rc4

# %%
from google.colab import files
uploaded_file = files.upload()

# %%
uploaded_file_name = next(iter(uploaded_file))
print(uploaded_file_name)

# %% [markdown]
# これだと毎回やる必要あり

# %%
import cv2

orig = cv2.imread('lena.jpg')
lena = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

plt.imshow(lena)

# %%
lena.shape
# Out:
# (400, 400, 3)

# %%
lena = lena / 255.0

# %%
from matplotlib import pyplot as plt

plt.imshow(lena)

# %%
import cv2
lena = cv2.imread('lena.jpg')
width,height=100,100
half_lena = cv2.resize(lena,(width,height))

# %% [markdown]
# 大事！リサイズ

# %%
from matplotlib import pyplot as plt

plt.imshow(half_lena)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import os.path

def clearLabel(_ax):
  
  return _ax
  
fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
clearLabel(ax1)
show_img1 = lena 
plt.imshow(show_img1)

ax2 = fig.add_subplot(1, 2, 2)
clearLabel(ax2)
show_img2 = half_lena
plt.imshow(show_img2)

plt.show()

# %% [markdown]
# ↓

# %% [markdown]
# ↑

# %%
from matplotlib import pyplot as plt

plt.imshow(half_lena)

# %%
import cv2
lena = cv2.imread('lena.jpg')
gauss_lena=cv2.GaussianBlur(lena,(21,21),0)

# %% [markdown]
# 大事！ノイズ

# %%
from matplotlib import pyplot as plt

plt.imshow(gauss_lena)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import os.path

def clearLabel(_ax):
  
  return _ax
  
fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
clearLabel(ax1)
show_img1 = lena 
plt.imshow(show_img1)

ax2 = fig.add_subplot(1, 2, 2)
clearLabel(ax2)
show_img2 = gauss_lena
plt.imshow(show_img2)

plt.show()

# %% [markdown]
# ここから

# %% [markdown]
# ドライブからファイル欲しかったら、、、

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# 上記の方法で調べたファイルのID
file_id = "1g5ZfFNVRWfSrlL3HIW51jn9ZIpjwyK7m"
drive_file = drive.CreateFile({'id': file_id})

# ファイルの取得
drive_file.GetContentFile("lena.jpg")

# %%
# 上記の方法で調べたファイルのID
file_id = "1l4NwTXWv2oKRhPnMaOZW87vkfqoWTyZg"
drive_file = drive.CreateFile({'id': file_id})

# ファイルの取得
drive_file.GetContentFile("minilena.jpg")

# %% [markdown]
# そして、、、
#
# ファイルから画像取り出す、それを保存

# %%
## ファイルにある「lena.jpg」画像ファイルを読み込む
import cv2
lena = cv2.imread('/content/lena.jpg')

## googledriveの中から取り出すなら、/content/drive/My Drive/〇〇.jpg

# %%
import cv2

orig = cv2.imread('lena.jpg')
lena = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# %%
## 画像の表示
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(lena)

# %%
## 画像の保存
cv2.imwrite('/content/lena.jpg', lena)
# Out:
# True

# %% [markdown]
# lena400を作る

# %%
import cv2

orig = cv2.imread('lena.jpg')
lena400 = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

plt.imshow(lena400)

# %%
## 画像の保存(resize_lenaというフォルダ作っておく)
cv2.imwrite('/content/resize_lena/lena400.jpg', lena400)
# Out:
# True

# %% [markdown]
# lena200を作る

# %%
import cv2
lena = cv2.imread('lena400.jpg')
width,height=200,200
lena200 = cv2.resize(lena400,(width,height))

# %%
from matplotlib import pyplot as plt

plt.imshow(lena200)

# %%
## 画像の保存
cv2.imwrite('/content/resize_lena/lena200.jpg', lena200)
# Out:
# True

# %% [markdown]
# lena100を作る

# %%
import cv2
lena = cv2.imread('lena400.jpg')
width,height=100,100
lena100 = cv2.resize(lena400,(width,height))

# %%
from matplotlib import pyplot as plt

plt.imshow(lena100)

# %%
## 画像の保存
cv2.imwrite('/content/resize_lena/lena100.jpg', lena100)
# Out:
# True

# %% [markdown]
# これらを配列にしていじる
#
# →うまくいかず

# %%
resize_lena = [lena400, lena200, lena100]

# %%
len(resize_lena)
# Out:
# 3

# %%
from matplotlib import pyplot as plt
plt.figure()
plt.imshow(resize_lena[0])
plt.show()

# %%
import cv2

for i in range(3):
    resize_lena=resize_lena[i]
    gauss_lena=cv2.GaussianBlur(resize_lena,(21,21),0)

# %%
import cv2

for i in range(3):
    print(i)

# %%
len(gauss_lena)
# Out:
# 3

# %% [markdown]
# 例えば、フォルダの画像すべてのサイズを3分の1に
#
# lena400,200,100をすべて3分の1に　計6枚
#
# (あらかじめresize_lenaに3枚のlena画像(400×400, 200×200, 100×100)が入れてあるところからスタート)

# %%
import os
import glob
from PIL import Image

files = glob.glob('/content/resize_lena/*.jpg')

for f in files:
    img = Image.open(f)
    img_resize = img.resize((int(img.width / 3), int(img.height / 3)))
    title, ext = os.path.splitext(f)
    img_resize.save(title + '_third' + ext)

# %%
import cv2
lena400_third = cv2.imread('/content/resize_lena/lena400_third.jpg')

# %%
from matplotlib import pyplot as plt

plt.imshow(lena400_third)

# %% [markdown]
# 今度は、そのフォルダの画像すべてにガウシアンノイズを付加
#
# lena400,200,100とそれぞれを3分の1にしたものすべてにノイズ　計12枚

# %%
import cv2
import os
import glob
from PIL import Image, ImageFilter

files = glob.glob('/content/resize_lena/*.jpg')


for f in files:
    img = Image.open(f)
    img_gauss = img.filter(ImageFilter.GaussianBlur(1.5))
    title, ext = os.path.splitext(f)
    img_gauss.save(title + '_gauss' + ext)

# %%
import cv2
lena400_third_gauss = cv2.imread('/content/resize_lena/lena400_third_gauss.jpg')

# %%
from matplotlib import pyplot as plt

plt.imshow(lena400_third_gauss)
